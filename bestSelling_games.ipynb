# %% [markdown]
# <a href="https://colab.research.google.com/github/matheuskbraga/data-structure/blob/main/bestSelling_games.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('bestSelling_games.csv')

# %%
df
# Out:
#                    game_name  reviews_like_rate  all_reviews_number  \
# 0           Counter-Strike 2                 86             8803754
# 1        PUBG: BATTLEGROUNDS                 59             2554482
# 2      ELDEN RING NIGHTREIGN                 77               53426
# 3     The Last of Us™ Part I                 79               45424
# 4      Red Dead Redemption 2                 92              672140
# ...                      ...                ...                 ...
# 2375            Wooden House                 38                 147
# 2376    Shoot. Push. Repeat.                 84                  65
# 2377          X2: The Threat                 83                 416
# 2378                !AnyWay!                 71                 498
# 2379          UBERMOSH:OMEGA                 93                 314
#
#       release_date           developer  \
# 0     21 Aug, 2012               Valve
# 1     21 Dec, 2017    PUBG Corporation
# ...

# %%
df[df['price'] == 0]
# Out:
#                                   game_name  reviews_like_rate  \
# 0                          Counter-Strike 2                 86
# 1                       PUBG: BATTLEGROUNDS                 59
# 5                                    Dota 2                 81
# 8                Game of Thrones: Kingsroad                 61
# 17                            Apex Legends™                 67
# ...                                     ...                ...
# 2249                                 Undawn                 54
# 2273  Flowers Blooming at the End of Summer                 95
# 2304                                 Banana                 82
# 2362                       BLOCKPOST LEGACY                 74
# 2372                              Dino Cats                 91
#
#       all_reviews_number  release_date           developer  \
# 0                8803754  21 Aug, 2012               Valve
# 1                2554482  21 Dec, 2017    PUBG Corporation
# ...

# %%
df[df['reviews_like_rate'] > 95]
# Out:
#                          game_name  reviews_like_rate  all_reviews_number  \
# 14                        R.E.P.O.                 96              147407
# 26                   Left 4 Dead 2                 97              732065
# 31                      Schedule I                 98              184389
# 40          Euro Truck Simulator 2                 97              657017
# 47              The Planet Crafter                 96               50216
# ...                            ...                ...                 ...
# 2356           Where Rabbits 兔子在哪里                 96                  63
# 2364         MEMOLOGY 2: OLD TIMES                 96                 219
# 2366   卖萌恶霸喵霸霸 Cute Bully Nyanbaba                 98                 135
# 2368                     Cute Cats                 96                 468
# 2370  GLAD VALAKAS TOWER DEFENCE 2                 97                  91
#
#       release_date        developer  \
# 14    26 Feb, 2025         semiwork
# ...

# %%
df_game = df[(df['price'] <= 50) & (df['reviews_like_rate'] >= 95)]
df_game
# Out:
#                          game_name  reviews_like_rate  all_reviews_number  \
# 14                        R.E.P.O.                 96              147407
# 15           Detroit: Become Human                 95              143663
# 25     Clair Obscur: Expedition 33                 95               69546
# 26                   Left 4 Dead 2                 97              732065
# 31                      Schedule I                 98              184389
# ...                            ...                ...                 ...
# 2364         MEMOLOGY 2: OLD TIMES                 96                 219
# 2365     101 Cats Hidden in Cancun                 95                  21
# 2366   卖萌恶霸喵霸霸 Cute Bully Nyanbaba                 98                 135
# 2368                     Cute Cats                 96                 468
# 2370  GLAD VALAKAS TOWER DEFENCE 2                 97                  91
#
#       release_date             developer  \
# ...

# %%
df_game[['game_name', 'user_defined_tags']]
# Out:
#                          game_name  \
# 14                        R.E.P.O.
# 15           Detroit: Become Human
# 25     Clair Obscur: Expedition 33
# 26                   Left 4 Dead 2
# 31                      Schedule I
# ...                            ...
# 2364         MEMOLOGY 2: OLD TIMES
# 2365     101 Cats Hidden in Cancun
# 2366   卖萌恶霸喵霸霸 Cute Bully Nyanbaba
# 2368                     Cute Cats
# 2370  GLAD VALAKAS TOWER DEFENCE 2
#
#                                       user_defined_tags
# 14                                 Early Access, Horror
# 15                             Story Rich, Visual Novel
# 25    Turn-Based, Combat, Story Rich, Fantasy, JRPG,...
# 26                        FPS, Action, Survival, Horror
# 31         Early Access, Simulation, Action, Open World
# ...                                                 ...
# 2364                                                RPG
# 2365                                       Cute, Puzzle
# ...
